# %%
import pandas
#from collections import Counter
import matplotlib.pyplot as plt

# %%
df = pandas.read_csv("/home/name/Downloads/www.log", delimiter = "\t", names=['IP', 'Date', 'Query', 'Result', 'Byte', 'Refer', 'Agent'])

# %%
#count = Counter(df['IP'])
#count.most_common(10)

##count = df['IP'].value_counts()
##plt.figure()
##count[:10].plot(kind='barh', rot=0)
##plt.show()

# %%
df
# Out:
#                       IP                        Date  \
# 0           207.46.13.85  05/Jun/2016:03:23:06 +0300
# 1          207.46.13.185  05/Jun/2016:03:23:11 +0300
# 2           207.46.13.85  05/Jun/2016:03:23:37 +0300
# 3            37.9.118.28  05/Jun/2016:03:24:10 +0300
# 4        109.234.156.234  05/Jun/2016:03:24:51 +0300
# 5           85.10.201.55  05/Jun/2016:03:26:35 +0300
# 6          78.47.115.117  05/Jun/2016:03:26:38 +0300
# 7          78.47.115.117  05/Jun/2016:03:27:10 +0300
# 8          78.47.115.117  05/Jun/2016:03:27:10 +0300
# 9          78.47.115.117  05/Jun/2016:03:27:10 +0300
# 10         78.47.115.117  05/Jun/2016:03:27:10 +0300
# 11         78.47.115.117  05/Jun/2016:03:27:11 +0300
# 12         78.47.115.117  05/Jun/2016:03:27:11 +0300
# 13         78.47.115.117  05/Jun/2016:03:27:11 +0300
# 14         78.47.115.117  05/Jun/2016:03:27:12 +0300
# 15         78.47.115.117  05/Jun/2016:03:27:12 +0300
# 16         78.47.115.117  05/Jun/2016:03:27:13 +0300
# ...
